# %%
report_title = pd.read_excel(
    file_path,
    sheet_name="Данные",
    header=None,
    nrows=1
).iloc[0, 0]

# Veriyi oku
df = pd.read_excel(
    file_path,
    sheet_name="Данные",
    header=1
)

df.columns = df.columns.str.strip()
df = df.dropna(how="all").reset_index(drop=True)

df.head()
# Out:
#   Номенклатура              Поставщик              Производитель  \
# 0    Продукт 1  Поставщик 1 г. Москва  ООО Производитель номер 1
# 1    Продукт 1  Поставщик 1 г. Москва  ООО Производитель номер 1
# 2    Продукт 1  Поставщик 1 г. Москва  ООО Производитель номер 1
# 3    Продукт 2  Поставщик 2 г. Москва  ООО Производитель номер 1
# 4    Продукт 3  Поставщик 2 г. Москва  ООО Производитель номер 1
#
#    Количество продажи  Сумма продажи  Цена продажи Адрес Номер накладной  \
# 0                   1            100           100     -      Н-11-00-11
# 1                   1            100           100     -      Н-11-00-12
# 2                   1            100           100     -      Н-11-00-13
# 3                   1            100           100     -      Н-11-00-14
# 4                   1            100           100     -      Н-11-00-15
#
#   Дата накладной
# 0     2025-04-01
# 1     2025-04-01
# 2     2025-04-01
# 3     2025-04-02
# 4     2025-04-03

# %%
str_cols = df.select_dtypes(include="object").columns

# Baştaki/sondaki boşlukları sil
df[str_cols] = df[str_cols].apply(lambda x: x.str.strip())

# Birden fazla boşluğu tek boşluğa indir
df[str_cols] = df[str_cols].apply(lambda x: x.str.replace(r"\s+", " ", regex=True))

# "-" veya sadece boşluk içeren değerleri NaN yap
df[str_cols] = df[str_cols].apply(lambda x: x.replace(r"^\s*-\s*$", pd.NA, regex=True))

# Boş stringleri NaN yap
df[str_cols] = df[str_cols].apply(lambda x: x.replace("", pd.NA))

# Kolon isimlerini de temizle
df.columns = df.columns.str.strip().str.replace(r"\s+", " ", regex=True)


df.head(10)
# Out:
#   Номенклатура              Поставщик              Производитель  \
# 0    Продукт 1  Поставщик 1 г. Москва  ООО Производитель номер 1
# 1    Продукт 1  Поставщик 1 г. Москва  ООО Производитель номер 1
# 2    Продукт 1  Поставщик 1 г. Москва  ООО Производитель номер 1
# 3    Продукт 2  Поставщик 2 г. Москва  ООО Производитель номер 1
# 4    Продукт 3  Поставщик 2 г. Москва  ООО Производитель номер 1
# 5    Продукт 3  Поставщик 2 г. Москва  ООО Производитель номер 1
# 6    Продукт 1  Поставщик 1 г. Москва  ООО Производитель номер 2
# 7    Продукт 2  Поставщик 2 г. Москва  ООО Производитель номер 2
# 8    Продукт 3  Поставщик 2 г. Москва  ООО Производитель номер 2
# 9    Продукт 3  Поставщик 2 г. Москва  ООО Производитель номер 2
#
#    Количество продажи  Сумма продажи  Цена продажи Адрес Номер накладной  \
# 0                   1            100           100  <NA>      Н-11-00-11
# 1                   1            100           100  <NA>      Н-11-00-12
# 2                   1            100           100  <NA>      Н-11-00-13
# 3                   1            100           100  <NA>      Н-11-00-14
# 4                   1            100           100  <NA>      Н-11-00-15
# 5                   1            100           100  <NA>             NaN
# 6                   1            100           100  <NA>      Н-11-00-16
# 7                   1            100           100  <NA>      Н-11-00-17
# 8                   1            100           100  <NA>      Н-11-00-18
# 9                   1            100           100  <NA>      Н-11-00-19
#
#   Дата накладной
# 0     2025-04-01
# 1     2025-04-01
# 2     2025-04-01
# 3     2025-04-02
# 4     2025-04-03
# 5     2025-04-03
# 6     2025-04-01
# 7     2025-04-02
# 8     2025-04-03
# 9     2025-04-03

# %%
df.drop("Адрес", axis=1, inplace=True)

df.head()
# Out:
#   Номенклатура              Поставщик              Производитель  \
# 0    Продукт 1  Поставщик 1 г. Москва  ООО Производитель номер 1
# 1    Продукт 1  Поставщик 1 г. Москва  ООО Производитель номер 1
# 2    Продукт 1  Поставщик 1 г. Москва  ООО Производитель номер 1
# 3    Продукт 2  Поставщик 2 г. Москва  ООО Производитель номер 1
# 4    Продукт 3  Поставщик 2 г. Москва  ООО Производитель номер 1
#
#    Количество продажи  Сумма продажи  Цена продажи Номер накладной  \
# 0                   1            100           100      Н-11-00-11
# 1                   1            100           100      Н-11-00-12
# 2                   1            100           100      Н-11-00-13
# 3                   1            100           100      Н-11-00-14
# 4                   1            100           100      Н-11-00-15
#
#   Дата накладной
# 0     2025-04-01
# 1     2025-04-01
# 2     2025-04-01
# 3     2025-04-02
# 4     2025-04-03

# %%
df["Город"] = df["Поставщик"].str.extract(r"г\.\s*([А-Яа-яA-Za-z\- ]+)")

# Поставщик kolonundan şehir kısmını kaldır
df["Поставщик"] = df["Поставщик"].str.replace(r"\s*г\.\s*[А-Яа-яA-Za-z\- ]+", "", regex=True)

# Temizlik (boşluk vs.)
df["Поставщик"] = df["Поставщик"].str.strip()
df["Город"] = df["Город"].str.strip()

# Kontrol
print(df[["Поставщик", "Город"]].head())
# Out:
#      Поставщик   Город
# 0  Поставщик 1  Москва
# 1  Поставщик 1  Москва
# 2  Поставщик 1  Москва
# 3  Поставщик 2  Москва
# 4  Поставщик 2  Москва

# %%
df.head(10)
# Out:
#   Номенклатура    Поставщик              Производитель  Количество продажи  \
# 0    Продукт 1  Поставщик 1  ООО Производитель номер 1                   1
# 1    Продукт 1  Поставщик 1  ООО Производитель номер 1                   1
# 2    Продукт 1  Поставщик 1  ООО Производитель номер 1                   1
# 3    Продукт 2  Поставщик 2  ООО Производитель номер 1                   1
# 4    Продукт 3  Поставщик 2  ООО Производитель номер 1                   1
# 5    Продукт 3  Поставщик 2  ООО Производитель номер 1                   1
# 6    Продукт 1  Поставщик 1  ООО Производитель номер 2                   1
# 7    Продукт 2  Поставщик 2  ООО Производитель номер 2                   1
# 8    Продукт 3  Поставщик 2  ООО Производитель номер 2                   1
# 9    Продукт 3  Поставщик 2  ООО Производитель номер 2                   1
#
#    Сумма продажи  Цена продажи Номер накладной Дата накладной   Город
# 0            100           100      Н-11-00-11     2025-04-01  Москва
# 1            100           100      Н-11-00-12     2025-04-01  Москва
# 2            100           100      Н-11-00-13     2025-04-01  Москва
# 3            100           100      Н-11-00-14     2025-04-02  Москва
# 4            100           100      Н-11-00-15     2025-04-03  Москва
# 5            100           100             NaN     2025-04-03  Москва
# 6            100           100      Н-11-00-16     2025-04-01  Москва
# 7            100           100      Н-11-00-17     2025-04-02  Москва
# 8            100           100      Н-11-00-18     2025-04-03  Москва
# 9            100           100      Н-11-00-19     2025-04-03  Москва

# %%
# --- TARİH PARÇALAMA ---

df["Год"] = df["Дата накладной"].dt.year
df["Месяц"] = df["Дата накладной"].dt.month
df["День"] = df["Дата накладной"].dt.day

print(df[["Год", "Месяц" ,"День"]].head())
# Out:
#     Год  Месяц  День
# 0  2025      4     1
# 1  2025      4     1
# 2  2025      4     1
# 3  2025      4     2
# 4  2025      4     3

# %%
month_dict = {
    1: "Январь", 2: "Февраль", 3: "Март", 4: "Апрель",
    5: "Май", 6: "Июнь", 7: "Июль", 8: "Август",
    9: "Сентябрь", 10: "Октябрь", 11: "Ноябрь", 12: "Декабрь"
}

df["Месяц"] = df["Месяц"].map(month_dict)

df["Месяц"].head()
# Out:
# 0    Апрель
# 1    Апрель
# 2    Апрель
# 3    Апрель
# 4    Апрель
# Name: Месяц, dtype: object

# %%
df.isna().sum()[df.isna().sum() > 0]
# Out:
# Номер накладной    1
# dtype: int64

# %%
df.head(10)
# Out:
#   Номенклатура    Поставщик              Производитель  Количество продажи  \
# 0    Продукт 1  Поставщик 1  ООО Производитель номер 1                   1
# 1    Продукт 1  Поставщик 1  ООО Производитель номер 1                   1
# 2    Продукт 1  Поставщик 1  ООО Производитель номер 1                   1
# 3    Продукт 2  Поставщик 2  ООО Производитель номер 1                   1
# 4    Продукт 3  Поставщик 2  ООО Производитель номер 1                   1
# 5    Продукт 3  Поставщик 2  ООО Производитель номер 1                   1
# 6    Продукт 1  Поставщик 1  ООО Производитель номер 2                   1
# 7    Продукт 2  Поставщик 2  ООО Производитель номер 2                   1
# 8    Продукт 3  Поставщик 2  ООО Производитель номер 2                   1
# 9    Продукт 3  Поставщик 2  ООО Производитель номер 2                   1
#
#    Сумма продажи  Цена продажи Номер накладной Дата накладной   Город   Год  \
# 0            100           100      Н-11-00-11     2025-04-01  Москва  2025
# 1            100           100      Н-11-00-12     2025-04-01  Москва  2025
# 2            100           100      Н-11-00-13     2025-04-01  Москва  2025
# 3            100           100      Н-11-00-14     2025-04-02  Москва  2025
# 4            100           100      Н-11-00-15     2025-04-03  Москва  2025
# 5            100           100             NaN     2025-04-03  Москва  2025
# 6            100           100      Н-11-00-16     2025-04-01  Москва  2025
# 7            100           100      Н-11-00-17     2025-04-02  Москва  2025
# 8            100           100      Н-11-00-18     2025-04-03  Москва  2025
# 9            100           100      Н-11-00-19     2025-04-03  Москва  2025
#
#     Месяц  День
# 0  Апрель     1
# 1  Апрель     1
# 2  Апрель     1
# 3  Апрель     2
# 4  Апрель     3
# 5  Апрель     3
# 6  Апрель     1
# 7  Апрель     2
# 8  Апрель     3
# 9  Апрель     3

# %%
cols = [c for c in df.columns if c != "Номер накладной"]

mask_group = (
    df.duplicated(subset=cols, keep=False) &
    df.groupby(cols, dropna=False)["Номер накладной"]
      .transform(lambda x: x.isna().any() and x.notna().any())
)

# SADECE NaN olan satırları seç
mask_nan = mask_group & df["Номер накладной"].isna()

def highlight(row):
    if mask_nan.loc[row.name]:
        return ["background-color: red"] * len(row)
    elif mask_group.loc[row.name]:
        return ["background-color: yellow"] * len(row)
    return [""] * len(row)

df.style.apply(highlight, axis=1)
# Out:
# <style type="text/css">
# #T_cc4fc_row4_col0, #T_cc4fc_row4_col1, #T_cc4fc_row4_col2, #T_cc4fc_row4_col3, #T_cc4fc_row4_col4, #T_cc4fc_row4_col5, #T_cc4fc_row4_col6, #T_cc4fc_row4_col7, #T_cc4fc_row4_col8, #T_cc4fc_row4_col9, #T_cc4fc_row4_col10, #T_cc4fc_row4_col11 {
#   background-color: yellow;
# }
# #T_cc4fc_row5_col0, #T_cc4fc_row5_col1, #T_cc4fc_row5_col2, #T_cc4fc_row5_col3, #T_cc4fc_row5_col4, #T_cc4fc_row5_col5, #T_cc4fc_row5_col6, #T_cc4fc_row5_col7, #T_cc4fc_row5_col8, #T_cc4fc_row5_col9, #T_cc4fc_row5_col10, #T_cc4fc_row5_col11 {
#   background-color: red;
# }
# </style>
# <table id="T_cc4fc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cc4fc_level0_col0" class="col_heading level0 col0" >Номенклатура</th>
#       <th id="T_cc4fc_level0_col1" class="col_heading level0 col1" >Поставщик</th>
#       <th id="T_cc4fc_level0_col2" class="col_heading level0 col2" >Производитель</th>
#       <th id="T_cc4fc_level0_col3" class="col_heading level0 col3" >Количество продажи</th>
#       <th id="T_cc4fc_level0_col4" class="col_heading level0 col4" >Сумма продажи</th>
#       <th id="T_cc4fc_level0_col5" class="col_heading level0 col5" >Цена продажи</th>
#       <th id="T_cc4fc_level0_col6" class="col_heading level0 col6" >Номер накладной</th>
#       <th id="T_cc4fc_level0_col7" class="col_heading level0 col7" >Дата накладной</th>
#       <th id="T_cc4fc_level0_col8" class="col_heading level0 col8" >Город</th>
#       <th id="T_cc4fc_level0_col9" class="col_heading level0 col9" >Год</th>
#       <th id="T_cc4fc_level0_col10" class="col_heading level0 col10" >Месяц</th>
#       <th id="T_cc4fc_level0_col11" class="col_heading level0 col11" >День</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cc4fc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cc4fc_row0_col0" class="data row0 col0" >Продукт 1</td>
#       <td id="T_cc4fc_row0_col1" class="data row0 col1" >Поставщик 1</td>
#       <td id="T_cc4fc_row0_col2" class="data row0 col2" >ООО Производитель номер 1</td>
#       <td id="T_cc4fc_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_cc4fc_row0_col4" class="data row0 col4" >100</td>
#       <td id="T_cc4fc_row0_col5" class="data row0 col5" >100</td>
#       <td id="T_cc4fc_row0_col6" class="data row0 col6" >Н-11-00-11</td>
#       <td id="T_cc4fc_row0_col7" class="data row0 col7" >2025-04-01 00:00:00</td>
#       <td id="T_cc4fc_row0_col8" class="data row0 col8" >Москва</td>
#       <td id="T_cc4fc_row0_col9" class="data row0 col9" >2025</td>
#       <td id="T_cc4fc_row0_col10" class="data row0 col10" >Апрель</td>
#       <td id="T_cc4fc_row0_col11" class="data row0 col11" >1</td>
#     </tr>
#     <tr>
#       <th id="T_cc4fc_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_cc4fc_row1_col0" class="data row1 col0" >Продукт 1</td>
#       <td id="T_cc4fc_row1_col1" class="data row1 col1" >Поставщик 1</td>
#       <td id="T_cc4fc_row1_col2" class="data row1 col2" >ООО Производитель номер 1</td>
#       <td id="T_cc4fc_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_cc4fc_row1_col4" class="data row1 col4" >100</td>
#       <td id="T_cc4fc_row1_col5" class="data row1 col5" >100</td>
#       <td id="T_cc4fc_row1_col6" class="data row1 col6" >Н-11-00-12</td>
#       <td id="T_cc4fc_row1_col7" class="data row1 col7" >2025-04-01 00:00:00</td>
#       <td id="T_cc4fc_row1_col8" class="data row1 col8" >Москва</td>
#       <td id="T_cc4fc_row1_col9" class="data row1 col9" >2025</td>
#       <td id="T_cc4fc_row1_col10" class="data row1 col10" >Апрель</td>
#       <td id="T_cc4fc_row1_col11" class="data row1 col11" >1</td>
#     </tr>
#     <tr>
#       <th id="T_cc4fc_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_cc4fc_row2_col0" class="data row2 col0" >Продукт 1</td>
#       <td id="T_cc4fc_row2_col1" class="data row2 col1" >Поставщик 1</td>
#       <td id="T_cc4fc_row2_col2" class="data row2 col2" >ООО Производитель номер 1</td>
#       <td id="T_cc4fc_row2_col3" class="data row2 col3" >1</td>
#       <td id="T_cc4fc_row2_col4" class="data row2 col4" >100</td>
#       <td id="T_cc4fc_row2_col5" class="data row2 col5" >100</td>
#       <td id="T_cc4fc_row2_col6" class="data row2 col6" >Н-11-00-13</td>
#       <td id="T_cc4fc_row2_col7" class="data row2 col7" >2025-04-01 00:00:00</td>
#       <td id="T_cc4fc_row2_col8" class="data row2 col8" >Москва</td>
#       <td id="T_cc4fc_row2_col9" class="data row2 col9" >2025</td>
#       <td id="T_cc4fc_row2_col10" class="data row2 col10" >Апрель</td>
#       <td id="T_cc4fc_row2_col11" class="data row2 col11" >1</td>
#     </tr>
#     <tr>
#       <th id="T_cc4fc_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_cc4fc_row3_col0" class="data row3 col0" >Продукт 2</td>
#       <td id="T_cc4fc_row3_col1" class="data row3 col1" >Поставщик 2</td>
#       <td id="T_cc4fc_row3_col2" class="data row3 col2" >ООО Производитель номер 1</td>
#       <td id="T_cc4fc_row3_col3" class="data row3 col3" >1</td>
#       <td id="T_cc4fc_row3_col4" class="data row3 col4" >100</td>
#       <td id="T_cc4fc_row3_col5" class="data row3 col5" >100</td>
#       <td id="T_cc4fc_row3_col6" class="data row3 col6" >Н-11-00-14</td>
#       <td id="T_cc4fc_row3_col7" class="data row3 col7" >2025-04-02 00:00:00</td>
#       <td id="T_cc4fc_row3_col8" class="data row3 col8" >Москва</td>
#       <td id="T_cc4fc_row3_col9" class="data row3 col9" >2025</td>
#       <td id="T_cc4fc_row3_col10" class="data row3 col10" >Апрель</td>
#       <td id="T_cc4fc_row3_col11" class="data row3 col11" >2</td>
#     </tr>
#     <tr>
#       <th id="T_cc4fc_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_cc4fc_row4_col0" class="data row4 col0" >Продукт 3</td>
#       <td id="T_cc4fc_row4_col1" class="data row4 col1" >Поставщик 2</td>
#       <td id="T_cc4fc_row4_col2" class="data row4 col2" >ООО Производитель номер 1</td>
#       <td id="T_cc4fc_row4_col3" class="data row4 col3" >1</td>
#       <td id="T_cc4fc_row4_col4" class="data row4 col4" >100</td>
#       <td id="T_cc4fc_row4_col5" class="data row4 col5" >100</td>
#       <td id="T_cc4fc_row4_col6" class="data row4 col6" >Н-11-00-15</td>
#       <td id="T_cc4fc_row4_col7" class="data row4 col7" >2025-04-03 00:00:00</td>
#       <td id="T_cc4fc_row4_col8" class="data row4 col8" >Москва</td>
#       <td id="T_cc4fc_row4_col9" class="data row4 col9" >2025</td>
#       <td id="T_cc4fc_row4_col10" class="data row4 col10" >Апрель</td>
#       <td id="T_cc4fc_row4_col11" class="data row4 col11" >3</td>
#     </tr>
#     <tr>
#       <th id="T_cc4fc_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_cc4fc_row5_col0" class="data row5 col0" >Продукт 3</td>
#       <td id="T_cc4fc_row5_col1" class="data row5 col1" >Поставщик 2</td>
#       <td id="T_cc4fc_row5_col2" class="data row5 col2" >ООО Производитель номер 1</td>
#       <td id="T_cc4fc_row5_col3" class="data row5 col3" >1</td>
#       <td id="T_cc4fc_row5_col4" class="data row5 col4" >100</td>
#       <td id="T_cc4fc_row5_col5" class="data row5 col5" >100</td>
#       <td id="T_cc4fc_row5_col6" class="data row5 col6" >nan</td>
#       <td id="T_cc4fc_row5_col7" class="data row5 col7" >2025-04-03 00:00:00</td>
#       <td id="T_cc4fc_row5_col8" class="data row5 col8" >Москва</td>
#       <td id="T_cc4fc_row5_col9" class="data row5 col9" >2025</td>
#       <td id="T_cc4fc_row5_col10" class="data row5 col10" >Апрель</td>
#       <td id="T_cc4fc_row5_col11" class="data row5 col11" >3</td>
#     </tr>
#     <tr>
#       <th id="T_cc4fc_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_cc4fc_row6_col0" class="data row6 col0" >Продукт 1</td>
#       <td id="T_cc4fc_row6_col1" class="data row6 col1" >Поставщик 1</td>
#       <td id="T_cc4fc_row6_col2" class="data row6 col2" >ООО Производитель номер 2</td>
#       <td id="T_cc4fc_row6_col3" class="data row6 col3" >1</td>
#       <td id="T_cc4fc_row6_col4" class="data row6 col4" >100</td>
#       <td id="T_cc4fc_row6_col5" class="data row6 col5" >100</td>
#       <td id="T_cc4fc_row6_col6" class="data row6 col6" >Н-11-00-16</td>

# %%
display(df.head(10).style.apply(...))
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\IPython\core\formatters.py:406, in BaseFormatter.__call__(self, obj)
#     404     method = get_real_method(obj, self.print_method)
#     405     if method is not None:
# --> 406         return method()
#     407     return None
#     408 else:
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\style.py:405, in Styler._repr_html_(self)
#     400 """
#     401 Hooks into Jupyter notebook rich display system, which calls _repr_html_ by
#     402 default if an object is returned at the end of a cell.
#     403 """
#     404 if get_option("styler.render.repr") == "html":
# --> 405     return self.to_html()
#     406 return None
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\style.py:1345, in Styler.to_html(self, buf, table_uuid, table_attributes, sparse_index, sparse_columns, bold_headers, caption, max_rows, max_columns, encoding, doctype_html, exclude_styles, **kwargs)
#    1342     obj.set_caption(caption)
#    1344 # Build HTML string..
# -> 1345 html = obj._render_html(
#    1346     sparse_index=sparse_index,
#    1347     sparse_columns=sparse_columns,
#    1348     max_rows=max_rows,
#    1349     max_cols=max_columns,
#    1350     exclude_styles=exclude_styles,
#    1351     encoding=encoding or get_option("styler.render.encoding"),
#    1352     doctype_html=doctype_html,
#    1353     **kwargs,
#    1354 )
#    1356 return save_to_buffer(
#    1357     html, buf=buf, encoding=(encoding if buf is not None else None)
#    1358 )
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\style_render.py:204, in StylerRenderer._render_html(self, sparse_index, sparse_columns, max_rows, max_cols, **kwargs)
#     192 def _render_html(
#     193     self,
#     194     sparse_index: bool,
#    (...)
#     198     **kwargs,
#     199 ) -> str:
#     200     """
#     201     Renders the ``Styler`` including all applied styles to HTML.
#     202     Generates a dict with necessary kwargs passed to jinja2 template.
#     203     """
# --> 204     d = self._render(sparse_index, sparse_columns, max_rows, max_cols, "&nbsp;")
#     205     d.update(kwargs)
#     206     return self.template_html.render(
#     207         **d,
#     208         html_table_tpl=self.template_html_table,
#     209         html_style_tpl=self.template_html_style,
#     210     )
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\style_render.py:161, in StylerRenderer._render(self, sparse_index, sparse_columns, max_rows, max_cols, blank)
#     147 def _render(
#     148     self,
#     149     sparse_index: bool,
#    (...)
#     153     blank: str = "",
#     154 ):
#     155     """
#     156     Computes and applies styles and then generates the general render dicts.
#     157
#     158     Also extends the `ctx` and `ctx_index` attributes with those of concatenated
#     159     stylers for use within `_translate_latex`
#     160     """
# --> 161     self._compute()
#     162     dxs = []
#     163     ctx_len = len(self.index)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\style_render.py:256, in StylerRenderer._compute(self)
#     254 r = self
#     255 for func, args, kwargs in self._todo:
# --> 256     r = func(self)(*args, **kwargs)
#     257 return r
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\style.py:1726, in Styler._apply(self, func, axis, subset, **kwargs)
#    1724 axis = self.data._get_axis_number(axis)
#    1725 if axis == 0:
# -> 1726     result = data.apply(func, axis=0, **kwargs)
#    1727 else:
#    1728     result = data.T.apply(func, axis=0, **kwargs).T  # see GH 42005
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:10374, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10360 from pandas.core.apply import frame_apply
#   10362 op = frame_apply(
#   10363     self,
#   10364     func=func,
#    (...)
#   10372     kwargs=kwargs,
#   10373 )
# > 10374 return op.apply().__finalize__(self, method="apply")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\apply.py:916, in FrameApply.apply(self)
#     913 elif self.raw:
#     914     return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
# --> 916 return self.apply_standard()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\apply.py:1063, in FrameApply.apply_standard(self)
#    1061 def apply_standard(self):
#    1062     if self.engine == "python":
# -> 1063         results, res_index = self.apply_series_generator()
#    1064     else:
#    1065         results, res_index = self.apply_series_numba()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\apply.py:1071, in FrameApply.apply_series_generator(self)
#    1070 def apply_series_generator(self) -> tuple[ResType, Index]:
# -> 1071     assert callable(self.func)
#    1073     series_gen = self.series_generator
#    1074     res_index = self.result_index
#
# AssertionError:
